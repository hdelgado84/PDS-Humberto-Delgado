# %% [markdown]
# ## <img src="./logo_UTN.svg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 4
# #### Nombre y Apellido
#
# ***
# ## Filtrado

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
#  $$ y(k) = \frac{1}{N} \sum_{i=0}^{N-1} x(k-i)  $$
#
#  Para N = [3; 5]

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./eje1.jpg" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante la simulación computacional

# %%
## Inicialización del Notebook del TP4

import numpy as np
from pandas import DataFrame
from IPython.display import HTML
from scipy import signal as sig
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.io as sio   #para cargar archivo .mat
import scipy.fft as f
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

import matplotlib.pyplot as plt

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

def vertical_flaten(a):
    
    return a.reshape(a.shape[0],1)

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

ww, hh = sig.freqz(np.array([1, 2, 3]), 1)
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='ejemplo')

plt.title('FIR ejemplo')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

#H[n]=[1,1,1]

ww, hh = sig.freqz(np.array([1, 1, 1]), 3)

plt.figure(2)

plt.plot(ww, 20 * np.log10(abs(hh)), label='z2+z+1/3z2')

plt.title('FIR N=2')
plt.xlabel('Frequencia normalizada pi')
plt.ylabel('Modulo [dB]')
#plt.grid(which='both', axis='both')
#plt.axis([0,np.pi,-20,0])
plt.grid()
axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()



#H[n]=[1,1,1,1,1]

ww, hh = sig.freqz(np.array([1, 1, 1, 1, 1]), 5)

plt.figure(3)

plt.plot(ww, 20 * np.log10(abs(hh)), label='z4+z3+z2+z+1/5z4')

plt.title('FIR N=5')
plt.xlabel('Frequencia normalizada pi')
plt.ylabel('Modulo [dB]')
#plt.grid(which='both', axis='both')
#plt.axis([0,np.pi,-20,0])
plt.grid()
axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# $$ h(k) = (-1, 1) $$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./eje2.jpg" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
ww, hh = sig.freqz(np.array([-1, 1]), 1)

plt.figure(3)

plt.plot(ww, 20 * np.log10(abs(hh)), label='-z+1/z')

plt.title('FIR ')
plt.xlabel('Frequencia normalizada pi')
plt.ylabel('Modulo [dB]')
#plt.grid(which='both', axis='both')
#plt.axis([0,np.pi,-20,0])
plt.grid()
axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()
# Out:
# <ipython-input-4-73eb06567ef4>:8: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(ww, 20 * np.log10(abs(hh)), label='-z+1/z')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# <img src="./comb.png" align="center" width="30%" />
#
#
# Para $N= (2; 4)$ y $b = -1$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./eje3.jpg" align="center" width="100%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
#N=2
#H(Z)=(1+0+bZ-2)
#b=-1


ww, hh = sig.freqz(np.array([-1,0, 1]), 1)

plt.figure(4)

plt.plot(ww, 20 * np.log10(abs(hh)), label='-z+1/z')

plt.title('FIR ')
plt.xlabel('Frequencia normalizada pi')
plt.ylabel('Modulo [dB]')
#plt.grid(which='both', axis='both')
#plt.axis([0,np.pi,-20,0])
plt.grid()
axes_hdl = plt.gca()
axes_hdl.legend()
plt.show()


#N=4

ww, hh = sig.freqz(np.array([-1,0,0,0,1]), 1)

plt.figure(5)

plt.plot(ww, 20 * np.log10(abs(hh)), label='z4-1/z4')

plt.title('FIR ')
plt.xlabel('Frequencia normalizada pi')
plt.ylabel('Modulo [dB]')
#plt.grid(which='both', axis='both')
#plt.axis([0,np.pi,-20,0])
plt.grid()
axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()
# Out:
# <ipython-input-5-c568fc5016c6>:13: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(ww, 20 * np.log10(abs(hh)), label='-z+1/z')
# <ipython-input-5-c568fc5016c6>:32: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(ww, 20 * np.log10(abs(hh)), label='z4-1/z4')

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> En el archivo <i>ECG_TP4.mat</i> encontrará un registro electrocardiográfico (ECG) registrado durante una prueba de esfuerzo, junto con una serie de variables descriptas a continuación. Diseñe y aplique los filtros digitales necesarios para mitigar las siguientes fuentes de contaminación:
# </div>

# %% [markdown]
#  - Ruido causado por el movimiento de los electrodos (Alta frecuencia)
#  - Ruido muscular (Alta frecuencia)
#  - Movimiento de la línea de base del ECG, inducido en parte por la respiración (Baja frecuencia)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Los latidos presentes en el registro de ECG, alineados y clasificados (de origen normal y ventricular) poseen las siguientes características temporales y frecuenciales:
# </div>

# %% [markdown]
# <img src="./latidos_tiempo.png" align="center" width="80%" />
#
# <img src="./latido_promedio.png" align="center" width="80%" />
#
# <img src="./latidos_espectro.png" align="center" width="80%" />

# %% [markdown]
# ### Archivo *ECG_TP4.mat*
# (variables)
#  - **ecg_lead**: Registro de ECG muestreado a $fs=1$ KHz durante una prueba de esfuerzo
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular
#  - **qrs_detections**: vector con las localizaciones (en # de muestras) donde ocurren los latidos
#
# a) Establezca una plantilla de diseño para los filtros digitales que necesitará para que la señal de ECG se asemeje a los latidos promedio en cuanto a *suavidad* de los trazos y nivel isoeléctrico nulo.

# %%
# Defina la plantilla del filtro

#fs0 = 1?? # fin de la banda de detenida 0
#fc0 = 4?? # comienzo de la banda de paso
#fc1 = 15?? # fin de la banda de paso
#fs1 = 25?? # comienzo de la banda de detenida 1
Fs=1000


mat_struct = sio.loadmat('ECG_TP4.mat')

ecg = mat_struct['ecg_lead'] #Cargo el ecg
ecgf = ecg.flatten()
cant_muestras = len(ecg)

fx, Pxx_den = sig.welch(ecgf, fs=Fs,nperseg=2000,axis=0,scaling='spectrum',average='mean')
#plt.figure()
#plt.plot(fx,Pxx_den,'g')
arg=np.argmax(10*np.log10(Pxx_den/Pxx_den[0]))
#Amp=10*np.log10(Pxx_den/Pxx_den[0])[arg]
#Fcorte=Amp-3
plt.figure()
plt.title("periodograma en DB normalizado")
plt.plot(fx,10*np.log10(Pxx_den/Pxx_den[0]),'y')
#plt.axhline(Fcorte, color='green')
#plt.axvline(88, color='green')
plt.grid()

# %% [markdown]
# b) ¿Cómo obtuvo dichos valores?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Tome la muestra del ecg y le realicé el periodograma de Welch y mirando la grafica fui sacando las frecuencia para los filtros.Tome como criterio sabiendo de la teoria que es una señal de baja frecuencia y, mirando el periodograma se nota que hay gran contenido energetico en baja frecuencia llegando a 0 Hz, de acá que saco los limites del pasa alto stopband de 1Hz y bandpass de 5HZ, y llegando a los 50Hz en la grafica vemos la interferncia de la red de alimentación de 50Hz. Aca tengo que eliminar este contenido de alta frecuencia para mi señal, luego fijo el limite del pasabajo con banpass de 25Hz y stopband de 40Hz.
# </div>

# %% [markdown]
# c) Diseñe **al menos** dos filtros FIR y dos IIR para su comparación. Verifique que la respuesta en frecuencia responda a la plantilla de diseño

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################


#Filtro FIR  "metodo ventana"
Fsw=1000 #Hz
whs=1 #PA
whp=5  #PA
wlp=25#PB
wls=33 #PB

fcs=np.array([0,whs,whp,wlp,wls,Fsw/2])

Att=np.array([-60,-60,0,0,-40,-40])
Atv=10**(Att/20)
numtaps=905
xv,yv=sig.freqz(tapsV, [1])

plt.figure()
plt.plot(xv*(Fsw/2)/np.pi,20 * np.log10(abs(yv)))
plt.title("FIR Metodo Ventana")
plt.xlim(-1,50)
plt.ylim(-60,1)
plt.ylabel("Ganancia - DB")
plt.xlabel("Frecuencia [Hz]")
plt.grid()
plt.figure()
#fase
plt.title("Fase Filtro FIR Ventana")
plt.plot(xv*(Fsw/2)/np.pi,np.angle(yv))
plt.ylabel("fase [radian]")
plt.xlabel("Frecuencia Hz")
plt.xlim(-1,50)
plt.grid()
#Filtro FIR  "Algoritmo Remez"

Fsw=1000
whs=1#PA
whp=5#PA
wlp=25#PB
wls=33#PB

fcs=np.array([0,whs,whp,wlp,wls,Fsw/2])

numtaps=327 #242

Corem=sig.remez(numtaps, fcs, [0.01,1,0.01], weight=None, Hz=None, type='bandpass', fs=Fsw)
xvr,yvr=sig.freqz(Corem, [1])

plt.figure()
plt.plot((xvr*(Fsw/2)/np.pi),20 * np.log10(abs(yvr)))
plt.title("FIR algoritmo Remez")
plt.xlim(-1,50)
plt.ylim(-60,1)
plt.ylabel("Ganancia - DB")
plt.xlabel("Frecuencia [Hz]")
plt.grid()
#fase
plt.figure()
plt.title("Fase Filtro FIR Remez")
plt.plot(xv*(Fsw/2)/np.pi,np.angle(yvr))
plt.ylabel("fase [radian]")
plt.xlabel("Frecuencia Hz")
plt.xlim(-1,50)
plt.grid()

##################################
#                                #
#  Filtros IRR  Cauer y Cheby2   #
#                                #
##################################

#Realizó la plantilla con un Pasabanda

#Filtro IRR ElIPTICO Cauer
 

Fsi=1000

rp=1
rs=40

whs=2.0/(Fsi/2)#PA
whp=5.0/(Fsi/2)#PA
wlp=25.0/(Fsi/2)#PB
wls=33.0/(Fsi/2)#PB

gpass=0.5  #dB
gstop=40 #dB

sosCau=sig.iirdesign([whp,wlp], [whs,wls], gpass, gstop, analog=False, ftype='ellip', output='sos')#, fs=Fsi)
w,hba=sig.sosfreqz(sosCau)
plt.figure()
plt.title("irr design Pasabanda cauer")
plt.plot(w*(Fsi/2)/np.pi,20*np.log10(abs(hba)))
plt.xlim(0,60)
#plt.ylim(-60,1)
plt.xlabel("Frecuencia [Hz]")
plt.grid()
#Fase
plt.figure()
plt.title("Fase Filtro FIR Cauer")
plt.plot(w*(Fsw/2)/np.pi,np.angle(hba))
plt.ylabel("fase [radian]")
plt.xlabel("Frecuencia Hz")
plt.xlim(-1,50)
plt.grid()

#Pasabanda cheby irr

sosCheby2=sig.iirdesign([whp,wlp], [whs,wls], gpass, gstop, analog=False, ftype='cheby2', output='sos')
wchb2,hchb2=sig.sosfreqz(sosCheby2)

plt.figure()
plt.title("irr design Pasabanda Chby2 ")
plt.plot(wchb2*(Fsi/2)/np.pi,20*np.log10(abs(hchb2)))
plt.xlim(0,60)
plt.ylim(-70,1)
plt.xlabel("Frecuencia [Hz]")
plt.grid()

#fase

plt.figure()
plt.title("Fase Filtro FIR Chby2")
plt.plot(wchb2*(Fsw/2)/np.pi,np.angle(hchb2))
plt.ylabel("fase [radian]")
plt.xlabel("Frecuencia Hz")
plt.xlim(-1,50)
plt.grid()
# Out:
# <ipython-input-31-78e5be7b22b8>:96: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(w*(Fsi/2)/np.pi,20*np.log10(abs(hba)))
# <ipython-input-31-78e5be7b22b8>:117: RuntimeWarning: divide by zero encountered in log10
#   plt.plot(wchb2*(Fsi/2)/np.pi,20*np.log10(abs(hchb2)))

# %% [markdown]
# d) Evalúe el rendimiento de los filtros que haya diseñado:
#
#  1. Verifique que filtra las señales interferentes
#  2. Verifique que es inocuo en las zonas donde no hay interferentes

# %%
# Segmentos de interés #
########################
# Puede tomar como referencia los siguientes segmentos, aunque si lo considera, también
# puede incluir otros que considere importantes para evaluar el rendimiento.
fs=1000
zonas_con_interf_baja_frec = ( 
        np.array([12, 12.4]) *60*fs, # minutos a muestras
        np.array([15, 15.2]) *60*fs, # minutos a muestras
        )


zonas_sin_interf = ( 
        np.array([5, 5.2]) *60*fs, # minutos a muestras
        np.array([4000, 5500]), # muestras
        np.array([10e3, 11e3]), # muestras
        )

##########################################
# Acá podés generar los gráficos pedidos #
##########################################


#Zonas de muestras "con interferencia"

c=[]                                  #Saco los indices 
for d in zonas_con_interf_baja_frec:
    c.append(d.astype(int))           #convierto a Int para luego hacer los slices
    
ecg_muest1 = ecgf[c[0][0]:c[0][1]]    #hago los slices para las zonas de interes
ecg_muest2 = ecgf[c[1][0]:c[1][1]]    


#Zonas de muestras "sin interferencia"
cc=[]
for dd in zonas_sin_interf:
    cc.append(dd.astype(int))
    
ecg_muest3 = ecgf[cc[0][0]:cc[0][1]]    
ecg_muest4 = ecgf[cc[1][0]:cc[1][1]]
ecg_muest5 = ecgf[cc[2][0]:cc[2][1]]


#Filtrado FIR Señal con interferencia

#filtrado FIR con metodo Ventana

VenFir1=sig.filtfilt(tapsV,1,ecg_muest1)
VenFir2=sig.filtfilt(tapsV,1,ecg_muest2)
plt.figure()
plt.plot(VenFir1[0:4000],label="filtrada")
plt.plot(ecg_muest1[0:4000],label='con interferencia')
plt.title("muestra1 con interferencia filtro Ventana ")
plt.legend()
plt.figure()
plt.plot(VenFir2[0:4000],label="filtrada")
plt.plot(ecg_muest2[0:4000],label='con interferencia')
plt.title("muestra2 con interferencia filtro Ventana ")
plt.legend()
#Filtrado FIR con algoritmo Remez

RemFir1=sig.filtfilt(Corem,1,ecg_muest1)
RemFir2=sig.filtfilt(Corem,1,ecg_muest2)
plt.figure()
plt.plot(RemFir1[0:4000],label="filtrada")
plt.plot(ecg_muest1[0:4000],label='con interferencia')
plt.title("muestra1 con interferencia filtro FIR Remez ")
plt.legend()
plt.figure()
plt.plot(RemFir2[0:4000],label="filtrada")
plt.plot(ecg_muest2[0:4000],label='con interferencia')
plt.title("muestra2 con interferencia filtro FIR Remez ")
plt.legend()

#Filtrado FIR Señal sin interferencia

#filtrado FIR con metodo Ventana

VenFir3=sig.filtfilt(tapsV,1,ecg_muest3,padlen=1000)
VenFir4=sig.filtfilt(tapsV,1,ecg_muest4,padlen=1000)
VenFir5=sig.filtfilt(tapsV,1,ecg_muest5,padlen=100)
plt.figure()
plt.plot(VenFir3,label="filtrada")
plt.plot(ecg_muest3,label='sin interferencia')
plt.title("muestra 1 sin interferencai filtro Ventana ")
plt.legend()
plt.figure()
plt.plot(VenFir4,label="filtrada")
plt.plot(ecg_muest4,label='sin interferencia')
plt.title("muestra 2 sin interferencia filtro Ventana ")
plt.legend()
plt.figure()
plt.plot(VenFir5,label="filtrada")
plt.plot(ecg_muest5,label='sin interferencia')
plt.title("muestra 3 sin interferencia filtro Ventana ")
plt.legend()

#Filtrado FIR con algoritmo Remez

RemFir3=sig.filtfilt(Corem,1,ecg_muest3)
RemFir4=sig.filtfilt(Corem,1,ecg_muest4)
RemFir5=sig.filtfilt(Corem,1,ecg_muest5)
plt.figure()
plt.plot(RemFir3,label="filtrada")
plt.plot(ecg_muest3,label='sin interferencia')
plt.title("muestra1 sin interferencia filtro FIR Remez ")
plt.legend()
plt.figure()
plt.plot(RemFir4,Label="filtrada")
plt.plot(ecg_muest4,label='sin interferencia')
plt.title("muestra2 sin interferencia filtro FIR Remez ")
plt.legend()
plt.figure()
plt.plot(RemFir5,label="filtrada")
plt.plot(ecg_muest5,label='sin interferencia')
plt.title("muestra3 sin interferencia filtro FIR Remez ")
plt.legend()

#################################
#                               #
#  Filtrado con filtro IIR      #
#                               # 
#################################

#Con interferncia Cauer

CauFil1=sig.sosfilt(sosCau, ecg_muest1)
CauFil2=sig.sosfilt(sosCau, ecg_muest2)

plt.figure()
plt.plot(CauFil1[0:4000],label="filtrada")
plt.plot(ecg_muest1[0:4000],label='con interferencia')
plt.title("muestra 1 con inter  filtro Cauer ")
plt.legend()

plt.figure()
plt.plot(CauFil2[0:4000],label="filtrada")
plt.plot(ecg_muest2[0:4000],label='con interferencia')
plt.title("muestra 2 con inter  filtro Cauer ")
plt.legend()

#Sin interferencia Cauer

CauFil3=sig.sosfilt(sosCau, ecg_muest3)
CauFil4=sig.sosfilt(sosCau, ecg_muest4)
CauFil5=sig.sosfilt(sosCau, ecg_muest5)

plt.figure()
plt.plot(CauFil3,label="filtrada")
plt.plot(ecg_muest3,label='sin interferencia')
plt.title("muestra 1 sin inter  filtro Cuer ")
plt.legend()

plt.figure()
plt.plot(CauFil4,label="filtrada")
plt.plot(ecg_muest4,label='sin interferencia')
plt.title("muestra 2 sin inter  filtro Cauer ")
plt.legend()

plt.figure()
plt.plot(CauFil5,label="filtrada")
plt.plot(ecg_muest5,label='sin interferencia')
plt.title("muestra 3 sin inter  filtro Cauer ")
plt.legend()


#Con interferencia Cheby
ChebFil1=sig.sosfilt(sosCheby2, ecg_muest1)
ChebFil2=sig.sosfilt(sosCheby2, ecg_muest2)

plt.figure()
plt.plot(ChebFil1[0:4000],label="filtrada")
plt.plot(ecg_muest1[0:4000],label='con interferencia')
plt.title("muestra 1 con inter  filtro Cheby2 ")
plt.legend()

plt.figure()
plt.plot(ChebFil2[0:4000],label="filtrada")
plt.plot(ecg_muest2[0:4000],label='con interferencia')
plt.title("muestra 2 con inter  filtro Cheby2 ")
plt.legend()

#Sin interferencia Cheby2

ChebFil3=sig.sosfilt(sosCheby2, ecg_muest3)
ChebFil4=sig.sosfilt(sosCheby2, ecg_muest4)
ChebFil5=sig.sosfilt(sosCheby2, ecg_muest5)

plt.figure()
plt.plot(ChebFil3,label="filtrada")
plt.plot(ecg_muest3,label='sin interferencia')
plt.title("muestra 1 sin inter  filtro Cheby2 ")
plt.legend()

plt.figure()
plt.plot(ChebFil4,label="filtrada")
plt.plot(ecg_muest4,label='sin interferencia')
plt.title("muestra 2 sin inter  filtro Cheby2 ")
plt.legend()

plt.figure()
plt.plot(ChebFil5,label="filtrada")
plt.plot(ecg_muest5,label='sin interferencia')
plt.title("muestra 3 sin inter  filtro Cheby2 ")
plt.legend()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Los filtros que mejor funciona son los FIR, son los que mejor dejan pasar la señal sin interferencia (se ven afectadas igual), pienso que los IRR no andan bien por la alinealidad de fase que tienen y por eso las señale sin interferencia se ven afectadadas.Ambos tipos de filtros quitan un cierto nivel de continua que tiene el ECG debida a la contaminacón que produce la respiración.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> Utilice las siguientes metodologías <b>no lineales</b> de estimación-substracción para la remoción de la interferencia de línea de base, y compare con las técnicas lineales del punto anterior en las mismas regiones. Luego discuta las ventajas y desventajas de cada técnica.
# </div>

# %% [markdown]
# a) Estimación del movimiento de línea de base a partir del filtrado de mediana. A partir de la siguiente estimación del movimiento de línea de base
#
# $$ \hat{b} = \mathop{med}_{600} \{ \mathop{med}_{200} \{s\} \} $$
#
# Donde $s$ representa la señal de ECG a partir de la que estimamos el movimiento de la línea de base $ \hat{b}$. El operador $\mathop{med}_{200}$ calcula muestra a muestra la mediana en los 200 ms previos a la muestra actual. Luego dicha estimación la substraemos para estimar la actividad eléctrica cardíaca $\hat{x}$
#
# $$ \hat{x} = s - \hat{b} $$

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la implementación del <a href="https://docs.scipy.org/doc/scipy/reference/tutorial/signal.html#median-filter">filtro de mediana provista en <b>scipy.signal</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# b) Estimación del movimiento de línea de base a partir de los segmentos isoeléctricos de cada latido. A partir de las detecciones provistas, puede estimar aproximadamente el nivel isoeléctrico, es decir el momento donde la actividad eléctrica cardíaca es **nula**. El intervalo entre la onda P y Q, es un buen momento para estimar las características de las señales interferentes que originan el movimiento de la línea de base.
#
# <img src="./pq.png" align="center" width="80%" />
#
# Para la localización del segmento PQ puede valerse de la localización de cada latido (líneas rojas verticales) y a partir de la misma, anticipar un tiempo adecuado de manera tal de no incluir la onda P ni Q. Puede ayudarse con el latido promedio de un latido normal para establecer dicho intervalo.
#
# Recuerde que la señal de línea de base debe estar muestreada a la misma frecuencia que el ECG, por lo que debería remuestrear dicha señal (puede usar la función de interpolación spline para ello).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la función de interpolación <a href="https://docs.scipy.org/doc/scipy-0.18.1/reference/generated/scipy.interpolate.CubicSpline.html">spline <b>scipy.interpolate.CubicSpline</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>6)</b> Para la señal de ECG provista junto con este documento, aplique el concepto de <b>filtro adaptado</b> y otras técnicas de filtrado digital para diseñar un detector de latidos. Los patrones provistos son:
#
# </div>

# %% [markdown]
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Revise el concepto de filtro adaptado en <a href="http://en.wikipedia.org/wiki/Matched_filter">Wikipedia</a>, o la bibliografía de la materia (Porat 14.4.9).
# </div>

# %%
import scipy.io as sio

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# para listar las variables que hay en el archivo
#io.whosmat('ECG_TP4.mat')
mat_struct = sio.loadmat('./ECG_TP4.mat')

ecg_one_lead = vertical_flaten(mat_struct['ecg_lead'])
N = len(ecg_one_lead)

hb_1 = vertical_flaten(mat_struct['heartbeat_pattern1'])

plt.figure(1)
plt.plot(ecg_one_lead[5000:12000])

plt.figure(2)
plt.plot(hb_1)

# %% [markdown]
# a) Explique conceptualmente cómo podría realizar un detector de latidos con la señal resultante del filtro adaptado. Discuta la utilidad y limitaciones de este método.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
#
#    b) Realice la detección de los latidos, comparando las detecciones obtenidas con las que se incluyen en la variable **qrs_detections**. Proponga alguna métrica para cuantificar las diferencias.

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
